# %%
import requests
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

# %%
api_key = os.getenv("LASFM_API_KEY")
print(api_key)
# Out:
# None

# %%
url = " http://ws.audioscrobbler.com/2.0/"

# %%
api_key = os.getenv("LASTFM_API_KEY")
url = "https://ws.audioscrobbler.com/2.0/"

params = {
    "method": "chart.gettopartists",
    "api_key": api_key,
    "format": "json",
    "limit": 50
}

response = requests.get(url, params=params)
data = response.json()

# %%
response = requests.get(url, params=params)
response.status_code
# Out:
# 200

# %%
#nuestras llaves 
data.keys()
# Out:
# dict_keys(['artists'])

# %%
data["artists"].keys()
# Out:
# dict_keys(['artist', '@attr'])

# %%
data["artists"]["artist"][:2]
# Out:
# [{'name': 'The Weeknd',
#   'playcount': '1072030651',
#   'listeners': '5169363',
#   'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#   'url': 'https://www.last.fm/music/The+Weeknd',
#   'streamable': '0',
#   'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'small'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'medium'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'large'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'extralarge'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'mega'}]},
#  {'name': 'Radiohead',
#   'playcount': '1321785944',
#   'listeners': '8075683',
#   'mbid': 'a74b1b7f-71a5-4011-9441-d0b5e4122711',
#   'url': 'https://www.last.fm/music/Radiohead',
#   'streamable': '0',
#   'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'small'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'medium'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'large'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'extralarge'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'mega'}]}]

# %%
#Generamos el DataFrame
artists = data["artists"]["artist"]

df = pd.DataFrame(artists)
df.head()
# Out:
#              name   playcount listeners                                  mbid  \
# 0      The Weeknd  1072030651   5169363  c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# 1       Radiohead  1321785944   8075683  a74b1b7f-71a5-4011-9441-d0b5e4122711
# 2    Taylor Swift  3549523924   5802848  20244d07-534f-4eff-b4d4-930878889970
# 3  Kendrick Lamar   991845742   4959091  381086ea-f511-4aba-bdf9-71c753dc5077
# 4           Drake  1100103357   6586123  9fff2f8a-21e6-47de-a2b8-7f449929d43f
#
#                                         url streamable  \
# 0      https://www.last.fm/music/The+Weeknd          0
# 1       https://www.last.fm/music/Radiohead          0
# 2    https://www.last.fm/music/Taylor+Swift          0
# 3  https://www.last.fm/music/Kendrick+Lamar          0
# 4           https://www.last.fm/music/Drake          0
#
#                                                image
# 0  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 1  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 2  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 3  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 4  [{'#text': 'https://lastfm.freetls.fastly.net/...

# %%
#Casteamos los datos a int aquellos que son numéricos
df["playcount"] = df["playcount"].astype(int)

# %%
df["listeners"] = df["listeners"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        50 non-null     object
#  1   playcount   50 non-null     int64
#  2   listeners   50 non-null     int64
#  3   mbid        48 non-null     object
#  4   url         50 non-null     object
#  5   streamable  50 non-null     object
#  6   image       50 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 2.9+ KB

# %%
df["streamable"].unique()
# Out:
# array(['0'], dtype=object)

# %%
df.shape
# Out:
# (50, 7)

# %%
df.sort_values("playcount", ascending = False).head(10)
# Out:
#                   name   playcount  listeners  \
# 2         Taylor Swift  3549523924    5802848
# 14        Lana Del Rey  1513314368    5117837
# 6           Kanye West  1463540203    7801902
# 1            Radiohead  1321785944    8075683
# 4                Drake  1100103357    6586123
# 0           The Weeknd  1072030651    5169363
# 49         The Beatles  1070202416    6391688
# 5        Ariana Grande  1053196403    4349182
# 9   Tyler, The Creator  1007203348    4199143
# 7            Lady Gaga   993861520    7559715
#
#                                     mbid  \
# 2   20244d07-534f-4eff-b4d4-930878889970
# 14  b7539c32-53e7-4908-bda3-81449c367da6
# 6                                    NaN
# 1   a74b1b7f-71a5-4011-9441-d0b5e4122711
# 4   9fff2f8a-21e6-47de-a2b8-7f449929d43f
# 0   c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# 49  b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d
# 5   f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387
# 9   f6beac20-5dfe-4d1f-ae02-0b0a740aafd6
# 7   650e7db6-b795-4eb5-a702-5ea2fc46c848
#
#                                              url streamable  \
# 2         https://www.last.fm/music/Taylor+Swift          0
# 14        https://www.last.fm/music/Lana+Del+Rey          0
# 6           https://www.last.fm/music/Kanye+West          0
# 1            https://www.last.fm/music/Radiohead          0
# 4                https://www.last.fm/music/Drake          0
# 0           https://www.last.fm/music/The+Weeknd          0
# 49         https://www.last.fm/music/The+Beatles          0
# 5        https://www.last.fm/music/Ariana+Grande          0
# 9   https://www.last.fm/music/Tyler,+The+Creator          0
# 7            https://www.last.fm/music/Lady+Gaga          0
#
#                                                 image
# 2   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 14  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 6   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 1   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 4   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 0   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 49  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 5   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 9   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 7   [{'#text': 'https://lastfm.freetls.fastly.net/...

# %%
df.describe()
# Out:
#           playcount     listeners
# count  5.000000e+01  5.000000e+01
# mean   6.701685e+08  4.607334e+06
# std    5.365350e+08  1.857737e+06
# min    6.987041e+07  2.040558e+06
# 25%    3.359698e+08  3.129010e+06
# 50%    5.614525e+08  4.126626e+06
# 75%    7.901899e+08  6.154120e+06
# max    3.549524e+09  8.950442e+06

# %%
#limpiamos formato y nos quedamos con las columnas estadísticamente significativas

# %%
df = df[["name", 
         "playcount",
         "listeners"]]

# %%
df.to_csv("top_artist_lastfm.csv", index = False)

# %%
#SEGUNDA TABLA DE TRACKS PARA COMPLETAR

# %%
api_key = os.getenv("LASTFM_API_KEY")

url2 = "https://ws.audioscrobbler.com/2.0/"

params = {
    "method": "chart.gettoptracks",
    "api_key": API_KEY,
    "format": "json",
    "limit": 50
}

response2 = requests.get(url2, params=params)
data2 = response2.json()

# %%
response2 = requests.get(url2, params=params)
response2.status_code
# Out:
# 200

# %%
data2.keys()
# Out:
# dict_keys(['tracks'])

# %%
data2["tracks"].keys()
# Out:
# dict_keys(['track', '@attr'])

# %%
tracks = data2["tracks"]["track"]

# %%
df_tracks = pd.DataFrame(tracks)

# %%
df_tracks.head()
# Out:
#                        name duration playcount listeners  \
# 0          End of Beginning      159  30047095   1842715
# 1                HELICOPTER      160    916059    259280
# 2  Stateside + Zara Larsson      176   4836427    457591
# 3       Order of Protection      171    458952    227471
# 4             Fame Is a Gun      181  14415190    818427
#
#                                    mbid  \
# 0  74f3b043-c0b4-4590-8c10-bfc4e3a06fef
# 1  1add4052-879f-49ce-9961-8f095c800c61
# 2  ffbf7862-2476-4164-ac32-f5904ccefe0f
# 3  b6095c15-a093-46dc-9398-321857ccbaab
# 4  8a5a12d3-e00d-450b-8c26-e4f4495f9ea7
#
#                                                  url  \
# 0   https://www.last.fm/music/Djo/_/End+of+Beginning
# 1  https://www.last.fm/music/A$AP+Rocky/_/HELICOPTER
# 2  https://www.last.fm/music/PinkPantheress/_/Sta...
# 3  https://www.last.fm/music/A$AP+Rocky/_/Order+o...
# 4  https://www.last.fm/music/Addison+Rae/_/Fame+I...
#
#                          streamable  \
# 0  {'#text': '0', 'fulltrack': '0'}
# 1  {'#text': '0', 'fulltrack': '0'}
# 2  {'#text': '0', 'fulltrack': '0'}
# 3  {'#text': '0', 'fulltrack': '0'}
# 4  {'#text': '0', 'fulltrack': '0'}
#
#                                               artist  \
# 0  {'name': 'Djo', 'mbid': '83cedfd0-a118-48eb-ad...
# 1  {'name': 'A$AP Rocky', 'mbid': '25b7b584-d952-...
# 2  {'name': 'PinkPantheress', 'mbid': '7441014f-f...
# 3  {'name': 'A$AP Rocky', 'mbid': '25b7b584-d952-...
# 4  {'name': 'Addison Rae', 'mbid': '610b71d9-fa78...
#
#                                                image
# 0  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 1  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 2  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 3  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 4  [{'#text': 'https://lastfm.freetls.fastly.net/...

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        50 non-null     object
#  1   duration    50 non-null     object
#  2   playcount   50 non-null     object
#  3   listeners   50 non-null     object
#  4   mbid        44 non-null     object
#  5   url         50 non-null     object
#  6   streamable  50 non-null     object
#  7   artist      50 non-null     object
#  8   image       50 non-null     object
# dtypes: object(9)
# memory usage: 3.6+ KB

# %%
df_tracks["duration"] = df_tracks["duration"].astype(int)

# %%
df_tracks["playcount"] = df_tracks["playcount"].astype(int)

# %%
df_tracks["listeners"] = df_tracks["listeners"].astype(int)

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        50 non-null     object
#  1   duration    50 non-null     int64
#  2   playcount   50 non-null     int64
#  3   listeners   50 non-null     int64
#  4   mbid        44 non-null     object
#  5   url         50 non-null     object
#  6   streamable  50 non-null     object
#  7   artist      50 non-null     object
#  8   image       50 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 3.6+ KB

# %%
df_tracks["artist"] = df_tracks["artist"].apply(lambda x: x["name"])

# %%
df_tracks
# Out:
#                                name  duration  playcount  listeners  \
# 0                  End of Beginning       159   30047095    1842715
# 1                        HELICOPTER       160     916059     259280
# 2          Stateside + Zara Larsson       176    4836427     457591
# 3               Order of Protection       171     458952     227471
# 4                     Fame Is a Gun       181   14415190     818427
# 5                     STOLE YA FLOW       199     551866     208847
# 6               The Fate of Ophelia       226   20025362     906506
# 7                        Punk Rocky       234    1225507     268577
# 8                  STAY HERE 4 LIFE       346     506967     200068
# 9                         Lush Life       201   11128820    1271238
# 10             WHERE IS MY HUSBAND!       196    7065220     746733
# 11                     I Just Might       212     914292     251969
# 12                            Playa       227     402537     184032
# 13             Interrogation (Skit)        49     334635     182566
# 14                           4 Raws       147    5979251     520674
# 15                   NO TRESPASSING       195     389276     174949
# 16                     Midnight Sun       189    6877113     449758
# 17  I Thought I Saw Your Face Today       185    4960200     679858
# 18                  back to friends       199   20505188    1263105
# 19                   Stop Snitching       200     376969     166851
# 20                            Creep       235   56656449    3950276
# 21       The Less I Know the Better       217   45063411    2615322
# 22   Lover, You Should've Come Over       403   28090577    1511943
# 23        AIR FORCE (BLACK DEMARCO)       224     326843     151825
# 24                 Good Luck, Babe!       218   56409314    1989609
# 25            Every Breath You Take       251   24674926    2714613
# 26                   No One Noticed       236   29516520    1444649
# 27                             Stfu       178     309487     148321
# 28                           Sienna       224   16614931    1045602
# 29             Whiskey (Release Me)       245     327499     144341
# 30        So Easy (To Fall In Love)       170    4941506     627348
# 31                         Manchild       213   19576839    1091341
# 32                         Let Down       337   36925456    2390337
# 33                              505       305   54702467    2896692
# 34        DON'T BE DUMB / TRIP BABY       285     362941     139652
# 35             Locked Out of Heaven       233   23895913    2357536
# 36                         Gabriela       197   15108878     879423
# 37                            Tears       160   12638647     910290
# 38                       Man I Need       184    6053140     653094
# 39                            Duvet       203   38230787    1865278
# 40                  Sweater Weather       240   47343801    2847403
# 41                          ROBBERY       235     292238     130607
# 42                   Feel Good Inc.       236   37445413    3132123
# 43                      Lovers Rock       213   47337152    2066515
# 44               That's What I Like       206   16455705    1762107
# 45                             Iris       216   28638481    2186456
# 46                       Sports car       165   19537205     848484
# 47               BIRDS OF A FEATHER       183   52587674    2123270
# 48                          The End       214     240029     121597
# 49                Where's My Phone?       189     563894     120968
#
#                                     mbid  \
# 0   74f3b043-c0b4-4590-8c10-bfc4e3a06fef
# 1   1add4052-879f-49ce-9961-8f095c800c61
# 2   ffbf7862-2476-4164-ac32-f5904ccefe0f
# 3   b6095c15-a093-46dc-9398-321857ccbaab
# 4   8a5a12d3-e00d-450b-8c26-e4f4495f9ea7
# 5   de2089df-2937-4cae-9dd3-ab075c1f06e5
# 6   8670a098-6ab7-4e18-8ac0-0ec7259151f8
# 7   4f120766-a704-4abe-a643-a48f52e9fa34
# 8   d5079090-df75-4c65-b902-0b5cabc03e37
# 9   ea31f8e4-9925-40dd-b37d-bd37ef3918c6
# 10  8493b88b-faf1-4735-b329-2366ad52b955
# 11  781018b7-f4f0-4fae-9b41-f45ecbe34024
# 12  820dc61a-afb5-4887-b48b-45bc93373c09
# 13  157a4e5f-b68f-4e93-b120-20ca3ba6560e
# 14  747aa723-f6ec-4ef7-81a6-8e05cedbce2b
# 15  a1ee2221-3289-4cbd-90b4-6b97b8bc06b8
# 16  eca6e837-39fd-481e-869d-42ffc893e942
# 17  06332d33-891e-32ac-98c4-f564e7babffd
# 18  e374d8c3-da4b-42ce-84dd-26f7236907c3
# 19  1c3de693-375d-4562-981d-2cb2fb93a465
# 20                                   NaN
# 21  78be434c-0908-458f-9693-f16cdebb68ef
# 22                                   NaN
# 23  4847ef52-a082-4e38-942f-97892ee512e4
# 24  9d97dc85-01e2-400e-8a3f-40cd4790de59
# 25                                   NaN
# 26  d13a634b-9f69-4256-9415-b7e95aac101d
# 27  0c15209d-5c2c-4505-bb6e-bb89019dae6e
# 28  f3db7473-3a61-4053-a7ce-a8fe29dbe5fa
# 29  3b3bd1c0-d1c7-466b-82c4-62b50d455a37
# 30                                   NaN
# 31  b40bca50-273f-488f-811c-a37857916c3f
# 32  9e3e014f-14d1-47da-9712-0dc1dfe00421
# 33  1025dd60-a781-4f30-8b12-2ab8bdef509c
# 34  9bd97f4a-5769-443a-96b3-8fce5787e488
# 35  ce8e25c3-e0fa-4b47-8e1e-33dffe514bfa
# 36  dc28871e-b219-4c6b-a6fc-0b863b0e607d
# 37  68a6abbc-2a79-40cb-bdf2-a861bc94b2c6
# 38  cba278b0-f241-41ee-bf7c-6c20c3e69571
# 39  3f320603-c50a-4d6f-9b64-55f04528046a
# 40  c57fc620-9ca2-40be-95ec-2c498a2151a8
# 41  9ca584f4-6c7b-41ea-9317-03f47dd4f610
# 42                                   NaN
# 43  0a12c26b-c3be-4c9e-a963-a8719f7f2dcc
# 44                                   NaN
# 45  49c04d28-280a-4bfb-afb5-a5affcb373e9
# 46  62cabe70-9c46-4d9a-899c-91c361b679d8
# 47  3a7e1970-069c-4761-a6b2-9046e54406bc
# 48  8d5f1577-520d-4199-9c47-55d19942d9bb
# 49  9e577af2-d46a-4386-8225-8ce87bee39fa
#
#                                                   url  \
# 0    https://www.last.fm/music/Djo/_/End+of+Beginning
# 1   https://www.last.fm/music/A$AP+Rocky/_/HELICOPTER
# 2   https://www.last.fm/music/PinkPantheress/_/Sta...
# 3   https://www.last.fm/music/A$AP+Rocky/_/Order+o...
# 4   https://www.last.fm/music/Addison+Rae/_/Fame+I...
# 5   https://www.last.fm/music/A$AP+Rocky/_/STOLE+Y...
# 6   https://www.last.fm/music/Taylor+Swift/_/The+F...
# 7   https://www.last.fm/music/A$AP+Rocky/_/Punk+Rocky
# 8   https://www.last.fm/music/A$AP+Rocky/_/STAY+HE...
# 9   https://www.last.fm/music/Zara+Larsson/_/Lush+...
# 10  https://www.last.fm/music/RAYE/_/WHERE+IS+MY+H...
# 11  https://www.last.fm/music/Bruno+Mars/_/I+Just+...
# 12       https://www.last.fm/music/A$AP+Rocky/_/Playa
# 13  https://www.last.fm/music/A$AP+Rocky/_/Interro...
# 14        https://www.last.fm/music/EsDeeKid/_/4+Raws
# 15  https://www.last.fm/music/A$AP+Rocky/_/NO+TRES...
# 16  https://www.last.fm/music/Zara+Larsson/_/Midni...
# 17  https://www.last.fm/music/She+&+Him/_/I+Though...
# 18  https://www.last.fm/music/sombr/_/back+to+friends
# 19  https://www.last.fm/music/A$AP+Rocky/_/Stop+Sn...
# 20        https://www.last.fm/music/Radiohead/_/Creep
# 21  https://www.last.fm/music/Tame+Impala/_/The+Le...
# 22  https://www.last.fm/music/Jeff+Buckley/_/Lover...
# 23  https://www.last.fm/music/A$AP+Rocky/_/AIR+FOR...
# 24  https://www.last.fm/music/Chappell+Roan/_/Good...
# 25  https://www.last.fm/music/The+Police/_/Every+B...
# 26  https://www.last.fm/music/The+Mar%C3%ADas/_/No...
# 27        https://www.last.fm/music/A$AP+Rocky/_/Stfu
# 28  https://www.last.fm/music/The+Mar%C3%ADas/_/Si...
# 29  https://www.last.fm/music/A$AP+Rocky/_/Whiskey...
# 30  https://www.last.fm/music/Olivia+Dean/_/So+Eas...
# 31  https://www.last.fm/music/Sabrina+Carpenter/_/...
# 32     https://www.last.fm/music/Radiohead/_/Let+Down
# 33     https://www.last.fm/music/Arctic+Monkeys/_/505
# 34  https://www.last.fm/music/A$AP+Rocky/_/DON%27T...
# 35  https://www.last.fm/music/Bruno+Mars/_/Locked+...
# 36       https://www.last.fm/music/KATSEYE/_/Gabriela
# 37  https://www.last.fm/music/Sabrina+Carpenter/_/...
# 38  https://www.last.fm/music/Olivia+Dean/_/Man+I+...
# 39         https://www.last.fm/music/b%C3%B4a/_/Duvet
# 40  https://www.last.fm/music/The+Neighbourhood/_/...
# 41     https://www.last.fm/music/A$AP+Rocky/_/ROBBERY
# 42  https://www.last.fm/music/Gorillaz/_/Feel+Good...
# 43    https://www.last.fm/music/TV+Girl/_/Lovers+Rock
# 44  https://www.last.fm/music/Bruno+Mars/_/That%27...
# 45  https://www.last.fm/music/The+Goo+Goo+Dolls/_/...
# 46  https://www.last.fm/music/Tate+McRae/_/Sports+car
# 47  https://www.last.fm/music/Billie+Eilish/_/BIRD...
# 48     https://www.last.fm/music/A$AP+Rocky/_/The+End
# 49  https://www.last.fm/music/Mitski/_/Where%27s+M...
#
#                           streamable             artist  \
# 0   {'#text': '0', 'fulltrack': '0'}                Djo
# 1   {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 2   {'#text': '0', 'fulltrack': '0'}     PinkPantheress
# 3   {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 4   {'#text': '0', 'fulltrack': '0'}        Addison Rae
# 5   {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 6   {'#text': '0', 'fulltrack': '0'}       Taylor Swift
# 7   {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 8   {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 9   {'#text': '0', 'fulltrack': '0'}       Zara Larsson
# 10  {'#text': '0', 'fulltrack': '0'}               RAYE
# 11  {'#text': '0', 'fulltrack': '0'}         Bruno Mars
# 12  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 13  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 14  {'#text': '0', 'fulltrack': '0'}           EsDeeKid
# 15  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 16  {'#text': '0', 'fulltrack': '0'}       Zara Larsson
# 17  {'#text': '0', 'fulltrack': '0'}          She & Him
# 18  {'#text': '0', 'fulltrack': '0'}              sombr
# 19  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 20  {'#text': '0', 'fulltrack': '0'}          Radiohead
# 21  {'#text': '0', 'fulltrack': '0'}        Tame Impala
# 22  {'#text': '0', 'fulltrack': '0'}       Jeff Buckley
# 23  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 24  {'#text': '0', 'fulltrack': '0'}      Chappell Roan
# 25  {'#text': '0', 'fulltrack': '0'}         The Police
# 26  {'#text': '0', 'fulltrack': '0'}         The Marías
# 27  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 28  {'#text': '0', 'fulltrack': '0'}         The Marías
# 29  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 30  {'#text': '0', 'fulltrack': '0'}        Olivia Dean
# 31  {'#text': '0', 'fulltrack': '0'}  Sabrina Carpenter
# 32  {'#text': '0', 'fulltrack': '0'}          Radiohead
# 33  {'#text': '0', 'fulltrack': '0'}     Arctic Monkeys
# 34  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 35  {'#text': '0', 'fulltrack': '0'}         Bruno Mars
# 36  {'#text': '0', 'fulltrack': '0'}            KATSEYE
# 37  {'#text': '0', 'fulltrack': '0'}  Sabrina Carpenter
# 38  {'#text': '0', 'fulltrack': '0'}        Olivia Dean
# 39  {'#text': '0', 'fulltrack': '0'}                bôa
# 40  {'#text': '0', 'fulltrack': '0'}  The Neighbourhood
# 41  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 42  {'#text': '0', 'fulltrack': '0'}           Gorillaz
# 43  {'#text': '0', 'fulltrack': '0'}            TV Girl
# 44  {'#text': '0', 'fulltrack': '0'}         Bruno Mars
# 45  {'#text': '0', 'fulltrack': '0'}  The Goo Goo Dolls
# 46  {'#text': '0', 'fulltrack': '0'}         Tate McRae
# 47  {'#text': '0', 'fulltrack': '0'}      Billie Eilish
# 48  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 49  {'#text': '0', 'fulltrack': '0'}             Mitski
#
#                                                 image
# 0   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 1   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 2   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 3   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 4   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 5   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 6   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 7   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 8   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 9   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 10  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 11  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 12  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 13  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 14  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 15  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 16  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 17  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 18  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 19  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 20  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 21  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 22  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 23  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 24  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 25  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 26  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 27  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 28  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 29  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 30  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 31  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 32  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 33  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 34  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 35  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 36  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 37  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 38  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 39  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 40  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 41  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 42  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 43  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 44  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 45  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 46  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 47  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 48  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 49  [{'#text': 'https://lastfm.freetls.fastly.net/...

# %%
df_tracks = df_tracks[["name", 
                       "duration",
                       "playcount",
                       "listeners",
                      "artist"]]

# %%
df_tracks.to_csv("top_tracks_lastfm.csv", index = False)
