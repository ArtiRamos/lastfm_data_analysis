# %% [markdown]
# # Proyecto Colaborativo
#
# > El proyecto consiste en el desarrollo de un proceso ETL básico con el objetivo de realizar un análisis estadístico de datos.
#
# ## ETL - Extract, Transform, Load
#
# Un proceso (o pipeline) ETL es una secuencia de operaciones de **descarga, transformación y carga de datos**. La estructura de un ETL, por lo tanto, se desarrolla de manera secuencial.
# - Primero realizamos una **extracción automatizada** de información desde alguna fuente de datos, típicamente una **base de datos o API**.
# - Una vez los datos están todos extraídos, **se procesan** para facilitar las tareas para las cuales se van a utilizar estos datos. Por ejemplo, podemos transformar nuestros datos de una estructura de dos tablas relacionadas entre sí, en una estructura de una única tabla combinada. Durante esta etapa también se realiza la **limpieza de datos**, que consiste en ajustar la información a un formato fácilmente procesable (ej. convertir strings de fechas a objetos `datetime`, convertir valores como `--` o `?` en `np.nan` para facilitar análisis de valores perdidos, etc.).
# - Cuando los datos ya están transformados y listos para el caso de uso, se almacenan conservando este nuevo formato, con el objetivo de no repetir todo el proceso de extracción y transformación de nuevo cada vez que se quieran utilizar. El almacenamiento típicamente se realiza en una **base de datos**, o estructuras de almacenamiento más permisivas como **data lakes** y **sistemas de ficheros**. Esto último dependerá de la naturaleza de la información y de las restricciones técnicas y económicas del proyecto.
#
# Existen dos formas comunes de diseñar e implementar un proceso ETL:
# - La primera, y la más fácil, es una en la que extraemos todos los datos, luego procesamos todo, y luego almacenamos todo.
# - La segunda, un poco más difícil, pero a la vez robusta a grandes volúmenes de datos, consiste en procesar y almacenar la información sobre la marcha, mientras se está extrayendo.
#
# ## Fases del proyecto
#
# En este proyeco se espera la implementación completa de una pipeline ETL destinada a facilitar un análisis de datos de cara a un cliente final. Estas son las fases del proyecto:
#
# - **ETL**: Realizamos el proceso descrito anteriormente, mediante la técnica de implementación que prefieran. La fuente de datos debe ser una o varias API(s) pública(s) a elección del equipo y validada según el criterio del docente. Los datos se almacenarán en el sistema de ficheros del ordenador.
# - **Análisis de Datos**: Con los datos transformados y almacenados, se tiene que realizar un estudio y análisis de la información que contienen. El estudio tiene que tener un foco claro y unas preguntas objetivo que se desean responder. El estudio tiene que comprender la exploración de la información y la presentación de visualizaciones y medidas estadísticas que ayuden a responder a las preguntas objetivo.
# - **Entrega**: La entrega del proyecto se realizará a través del correo electrónico. Un representante del equipo enviará un email adjuntando el enlace al repositorio público de GitHub (u otro servicio cloud de Git, Como GitLab, BitBucket o Codeberg). En el repositorio tienen que estar presentes todos los notebooks utilizados para el trabajo, bien estructurados e idealmente enumerados en orden de ejecución para todo aquel que quiera probar el código. Es importante el uso correcto de `.gitignore` para evitar saturar el repositorio con ficheros y carpetas que no aporten valor al trabajo, así como para escribir en un fichero ignorado información sensible como credenciales de las APIs.

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = " http://ws.audioscrobbler.com/2.0/"

# %%
API_KEY = "29c90c00701a7497d7223d0ebe0b0c63"

url = "https://ws.audioscrobbler.com/2.0/"

params = {
    "method": "chart.gettopartists",
    "api_key": API_KEY,
    "format": "json",
    "limit": 50
}

response = requests.get(url, params=params)
data = response.json()

# %%
response = requests.get(url, params=params)
response.status_code
# Out:
# 200

# %%
data.keys()
# Out:
# dict_keys(['artists'])

# %%
data["artists"].keys()
# Out:
# dict_keys(['artist', '@attr'])

# %%
data["artists"]["artist"][:2]
# Out:
# [{'name': 'The Weeknd',
#   'playcount': '1070953019',
#   'listeners': '5166246',
#   'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#   'url': 'https://www.last.fm/music/The+Weeknd',
#   'streamable': '0',
#   'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'small'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'medium'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'large'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'extralarge'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'mega'}]},
#  {'name': 'Taylor Swift',
#   'playcount': '3546833443',
#   'listeners': '5799862',
#   'mbid': '20244d07-534f-4eff-b4d4-930878889970',
#   'url': 'https://www.last.fm/music/Taylor+Swift',
#   'streamable': '0',
#   'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'small'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'medium'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'large'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'extralarge'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'mega'}]}]

# %%
artists = data["artists"]["artist"]

df = pd.DataFrame(artists)
df.head()
# Out:
#              name   playcount listeners                                  mbid  \
# 0      The Weeknd  1070953019   5166246  c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# 1    Taylor Swift  3546833443   5799862  20244d07-534f-4eff-b4d4-930878889970
# 2       Radiohead  1320657387   8072132  a74b1b7f-71a5-4011-9441-d0b5e4122711
# 3  Kendrick Lamar   991074491   4956260  381086ea-f511-4aba-bdf9-71c753dc5077
# 4   Ariana Grande  1051950170   4346320  f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387
#
#                                         url streamable  \
# 0      https://www.last.fm/music/The+Weeknd          0
# 1    https://www.last.fm/music/Taylor+Swift          0
# 2       https://www.last.fm/music/Radiohead          0
# 3  https://www.last.fm/music/Kendrick+Lamar          0
# 4   https://www.last.fm/music/Ariana+Grande          0
#
#                                                image
# 0  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 1  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 2  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 3  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 4  [{'#text': 'https://lastfm.freetls.fastly.net/...

# %%
df["playcount"] = df["playcount"].astype(int)

# %%
df["listeners"] = df["listeners"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        50 non-null     object
#  1   playcount   50 non-null     int64
#  2   listeners   50 non-null     int64
#  3   mbid        48 non-null     object
#  4   url         50 non-null     object
#  5   streamable  50 non-null     object
#  6   image       50 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 2.9+ KB

# %%
df["streamable"].unique()
# Out:
# array(['0'], dtype=object)

# %%
df.shape
# Out:
# (50, 7)

# %%
df.sort_values("playcount", ascending = False).head(10)
# Out:
#                   name   playcount  listeners  \
# 1         Taylor Swift  3546833443    5799862
# 14        Lana Del Rey  1512009653    5114914
# 7           Kanye West  1462562966    7799218
# 2            Radiohead  1320657387    8072132
# 5                Drake  1098811856    6582793
# 0           The Weeknd  1070953019    5166246
# 49         The Beatles  1069606894    6389096
# 4        Ariana Grande  1051950170    4346320
# 8   Tyler, The Creator  1006358172    4196662
# 6            Lady Gaga   993115063    7556103
#
#                                     mbid  \
# 1   20244d07-534f-4eff-b4d4-930878889970
# 14  b7539c32-53e7-4908-bda3-81449c367da6
# 7                                    NaN
# 2   a74b1b7f-71a5-4011-9441-d0b5e4122711
# 5   9fff2f8a-21e6-47de-a2b8-7f449929d43f
# 0   c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# 49  b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d
# 4   f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387
# 8   f6beac20-5dfe-4d1f-ae02-0b0a740aafd6
# 6   650e7db6-b795-4eb5-a702-5ea2fc46c848
#
#                                              url streamable  \
# 1         https://www.last.fm/music/Taylor+Swift          0
# 14        https://www.last.fm/music/Lana+Del+Rey          0
# 7           https://www.last.fm/music/Kanye+West          0
# 2            https://www.last.fm/music/Radiohead          0
# 5                https://www.last.fm/music/Drake          0
# 0           https://www.last.fm/music/The+Weeknd          0
# 49         https://www.last.fm/music/The+Beatles          0
# 4        https://www.last.fm/music/Ariana+Grande          0
# 8   https://www.last.fm/music/Tyler,+The+Creator          0
# 6            https://www.last.fm/music/Lady+Gaga          0
#
#                                                 image
# 1   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 14  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 7   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 2   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 5   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 0   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 49  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 4   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 8   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 6   [{'#text': 'https://lastfm.freetls.fastly.net/...

# %%
df.describe()
# Out:
#           playcount     listeners
# count  5.000000e+01  5.000000e+01
# mean   6.694404e+08  4.604100e+06
# std    5.362196e+08  1.857881e+06
# min    6.943561e+07  2.030620e+06
# 25%    3.340421e+08  3.126427e+06
# 50%    5.610285e+08  4.123732e+06
# 75%    7.895143e+08  6.151632e+06
# max    3.546833e+09  8.947047e+06

# %%
df.to_csv("top_artist_lastfm.csv", index = False)

# %%
API_KEY = "29c90c00701a7497d7223d0ebe0b0c63"

url2 = "https://ws.audioscrobbler.com/2.0/"

params = {
    "method": "chart.gettoptracks",
    "api_key": API_KEY,
    "format": "json",
    "limit": 50
}

response2 = requests.get(url2, params=params)
data2 = response2.json()

# %%
response2 = requests.get(url2, params=params)
response2.status_code
# Out:
# 200

# %%
data2.keys()
# Out:
# dict_keys(['tracks'])

# %%
data2["tracks"].keys()
# Out:
# dict_keys(['track', '@attr'])

# %%
tracks = data2["tracks"]["track"]

# %%
df_tracks = pd.DataFrame(tracks)

# %%
df_tracks.head()
# Out:
#                        name duration playcount listeners  \
# 0          End of Beginning      159  29970287   1839761
# 1                HELICOPTER      161    820590    241951
# 2  Stateside + Zara Larsson      176   4683753    447433
# 3       Order of Protection        0    400803    211391
# 4             Fame Is a Gun      181  14346794    815574
#
#                                    mbid  \
# 0  74f3b043-c0b4-4590-8c10-bfc4e3a06fef
# 1  1add4052-879f-49ce-9961-8f095c800c61
# 2  ffbf7862-2476-4164-ac32-f5904ccefe0f
# 3                                   NaN
# 4  8a5a12d3-e00d-450b-8c26-e4f4495f9ea7
#
#                                                  url  \
# 0   https://www.last.fm/music/Djo/_/End+of+Beginning
# 1  https://www.last.fm/music/A$AP+Rocky/_/HELICOPTER
# 2  https://www.last.fm/music/PinkPantheress/_/Sta...
# 3  https://www.last.fm/music/A$AP+Rocky/_/Order+o...
# 4  https://www.last.fm/music/Addison+Rae/_/Fame+I...
#
#                          streamable  \
# 0  {'#text': '0', 'fulltrack': '0'}
# 1  {'#text': '0', 'fulltrack': '0'}
# 2  {'#text': '0', 'fulltrack': '0'}
# 3  {'#text': '0', 'fulltrack': '0'}
# 4  {'#text': '0', 'fulltrack': '0'}
#
#                                               artist  \
# 0  {'name': 'Djo', 'mbid': '83cedfd0-a118-48eb-ad...
# 1  {'name': 'A$AP Rocky', 'mbid': '25b7b584-d952-...
# 2  {'name': 'PinkPantheress', 'mbid': '7441014f-f...
# 3  {'name': 'A$AP Rocky', 'url': 'https://www.las...
# 4  {'name': 'Addison Rae', 'mbid': '610b71d9-fa78...
#
#                                                image
# 0  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 1  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 2  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 3  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 4  [{'#text': 'https://lastfm.freetls.fastly.net/...

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        50 non-null     object
#  1   duration    50 non-null     object
#  2   playcount   50 non-null     object
#  3   listeners   50 non-null     object
#  4   mbid        32 non-null     object
#  5   url         50 non-null     object
#  6   streamable  50 non-null     object
#  7   artist      50 non-null     object
#  8   image       50 non-null     object
# dtypes: object(9)
# memory usage: 3.6+ KB

# %%
df_tracks["duration"] = df_tracks["duration"].astype(int)

# %%
df_tracks["playcount"] = df_tracks["playcount"].astype(int)

# %%
df_tracks["listeners"] = df_tracks["listeners"].astype(int)

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        50 non-null     object
#  1   duration    50 non-null     int64
#  2   playcount   50 non-null     int64
#  3   listeners   50 non-null     int64
#  4   mbid        32 non-null     object
#  5   url         50 non-null     object
#  6   streamable  50 non-null     object
#  7   artist      50 non-null     object
#  8   image       50 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 3.6+ KB

# %%
df_tracks["artist"] = df_tracks["artist"].apply(lambda x: x["name"])

# %%
df_tracks
# Out:
#                                name  duration  playcount  listeners  \
# 0                  End of Beginning       159   29970287    1839761
# 1                        HELICOPTER       161     820590     241951
# 2          Stateside + Zara Larsson       176    4683753     447433
# 3               Order of Protection         0     400803     211391
# 4                     Fame Is a Gun       181   14346794     815574
# 5               The Fate of Ophelia       226   19950287     904708
# 6                        Punk Rocky       234    1153004     258575
# 7                     STOLE YA FLOW         0     469085     192213
# 8                      I Just Might       212     859780     241825
# 9              WHERE IS MY HUSBAND!       196    7018239     743678
# 10                        Lush Life       201   11076724    1265803
# 11                 STAY HERE 4 LIFE         0     423212     182395
# 12                           4 Raws       147    5921497     515682
# 13  I Thought I Saw Your Face Today       185    4907764     674696
# 14             Interrogation (Skit)         0     294553     170338
# 15                     Midnight Sun       189    6802908     445397
# 16                  back to friends       199   20460559    1261400
# 17                            Playa         0     342248     168093
# 18                            Creep       235   56616730    3948879
# 19                   NO TRESPASSING         0     330622     159994
# 20       The Less I Know the Better       217   45030680    2613898
# 21                   Stop Snitching         0     321330     153429
# 22   Lover, You Should've Come Over       403   28048582    1510444
# 23                 Good Luck, Babe!       218   56377941    1988806
# 24            Every Breath You Take       251   24641918    2712692
# 25                   No One Noticed       236   29476640    1443288
# 26        So Easy (To Fall In Love)       170    4905646     624948
# 27                           Sienna       224   16575259    1044237
# 28                         Manchild       212   19536635    1090243
# 29                         Let Down       337   36886575    2389050
# 30        AIR FORCE (BLACK DEMARCO)         0     282238     140454
# 31                              505       305   54670673    2895476
# 32                             Stfu         0     269795     137665
# 33             Locked Out of Heaven       233   23872504    2355400
# 34                       Man I Need       184    6019477     651151
# 35                         Gabriela       197   15077806     877833
# 36                            Tears       160   12604722     909212
# 37             Whiskey (Release Me)         0     280162     132801
# 38                            Duvet       203   38202113    1863894
# 39                  Sweater Weather       240   47316367    2846085
# 40               That's What I Like       206   16431371    1759843
# 41                   Feel Good Inc.       236   37420117    3130781
# 42                      Lovers Rock       213   47306887    2065376
# 43                       Sports car       165   19504797     847472
# 44        DON'T BE DUMB / TRIP BABY         0     302670     127716
# 45                             Iris       216   28610133    2185155
# 46               BIRDS OF A FEATHER       183   52560175    2122371
# 47                      Purple Rain       447    6505749    1104012
# 48                          Dracula       205    6575817     763796
# 49                          ROBBERY         0     250738     120425
#
#                                     mbid  \
# 0   74f3b043-c0b4-4590-8c10-bfc4e3a06fef
# 1   1add4052-879f-49ce-9961-8f095c800c61
# 2   ffbf7862-2476-4164-ac32-f5904ccefe0f
# 3                                    NaN
# 4   8a5a12d3-e00d-450b-8c26-e4f4495f9ea7
# 5   8670a098-6ab7-4e18-8ac0-0ec7259151f8
# 6   4f120766-a704-4abe-a643-a48f52e9fa34
# 7                                    NaN
# 8   781018b7-f4f0-4fae-9b41-f45ecbe34024
# 9   8493b88b-faf1-4735-b329-2366ad52b955
# 10  ea31f8e4-9925-40dd-b37d-bd37ef3918c6
# 11                                   NaN
# 12  3cdb4139-a2de-4ff1-b92b-e1b2d00d8d06
# 13  06332d33-891e-32ac-98c4-f564e7babffd
# 14                                   NaN
# 15  eca6e837-39fd-481e-869d-42ffc893e942
# 16  e374d8c3-da4b-42ce-84dd-26f7236907c3
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
# 20  78be434c-0908-458f-9693-f16cdebb68ef
# 21                                   NaN
# 22                                   NaN
# 23  9d97dc85-01e2-400e-8a3f-40cd4790de59
# 24                                   NaN
# 25  d13a634b-9f69-4256-9415-b7e95aac101d
# 26                                   NaN
# 27  f3db7473-3a61-4053-a7ce-a8fe29dbe5fa
# 28  b40bca50-273f-488f-811c-a37857916c3f
# 29  9e3e014f-14d1-47da-9712-0dc1dfe00421
# 30                                   NaN
# 31  1025dd60-a781-4f30-8b12-2ab8bdef509c
# 32                                   NaN
# 33  c9b0bcfb-1f8b-49f5-9ab1-8a94d1975ff4
# 34  cba278b0-f241-41ee-bf7c-6c20c3e69571
# 35  cb6ddab8-e752-4508-b067-e5ebc9d5b21b
# 36  68a6abbc-2a79-40cb-bdf2-a861bc94b2c6
# 37                                   NaN
# 38  3f320603-c50a-4d6f-9b64-55f04528046a
# 39  c57fc620-9ca2-40be-95ec-2c498a2151a8
# 40                                   NaN
# 41                                   NaN
# 42  0a12c26b-c3be-4c9e-a963-a8719f7f2dcc
# 43  62cabe70-9c46-4d9a-899c-91c361b679d8
# 44                                   NaN
# 45  49c04d28-280a-4bfb-afb5-a5affcb373e9
# 46  3a7e1970-069c-4761-a6b2-9046e54406bc
# 47  4e0fa07f-f6b3-3f39-a0e8-3c0690798443
# 48  5b1c893a-16da-4e3d-b9b7-6cc57afc360c
# 49                                   NaN
#
#                                                   url  \
# 0    https://www.last.fm/music/Djo/_/End+of+Beginning
# 1   https://www.last.fm/music/A$AP+Rocky/_/HELICOPTER
# 2   https://www.last.fm/music/PinkPantheress/_/Sta...
# 3   https://www.last.fm/music/A$AP+Rocky/_/Order+o...
# 4   https://www.last.fm/music/Addison+Rae/_/Fame+I...
# 5   https://www.last.fm/music/Taylor+Swift/_/The+F...
# 6   https://www.last.fm/music/A$AP+Rocky/_/Punk+Rocky
# 7   https://www.last.fm/music/A$AP+Rocky/_/STOLE+Y...
# 8   https://www.last.fm/music/Bruno+Mars/_/I+Just+...
# 9   https://www.last.fm/music/RAYE/_/WHERE+IS+MY+H...
# 10  https://www.last.fm/music/Zara+Larsson/_/Lush+...
# 11  https://www.last.fm/music/A$AP+Rocky/_/STAY+HE...
# 12        https://www.last.fm/music/EsDeeKid/_/4+Raws
# 13  https://www.last.fm/music/She+&+Him/_/I+Though...
# 14  https://www.last.fm/music/A$AP+Rocky/_/Interro...
# 15  https://www.last.fm/music/Zara+Larsson/_/Midni...
# 16  https://www.last.fm/music/sombr/_/back+to+friends
# 17       https://www.last.fm/music/A$AP+Rocky/_/Playa
# 18        https://www.last.fm/music/Radiohead/_/Creep
# 19  https://www.last.fm/music/A$AP+Rocky/_/NO+TRES...
# 20  https://www.last.fm/music/Tame+Impala/_/The+Le...
# 21  https://www.last.fm/music/A$AP+Rocky/_/Stop+Sn...
# 22  https://www.last.fm/music/Jeff+Buckley/_/Lover...
# 23  https://www.last.fm/music/Chappell+Roan/_/Good...
# 24  https://www.last.fm/music/The+Police/_/Every+B...
# 25  https://www.last.fm/music/The+Mar%C3%ADas/_/No...
# 26  https://www.last.fm/music/Olivia+Dean/_/So+Eas...
# 27  https://www.last.fm/music/The+Mar%C3%ADas/_/Si...
# 28  https://www.last.fm/music/Sabrina+Carpenter/_/...
# 29     https://www.last.fm/music/Radiohead/_/Let+Down
# 30  https://www.last.fm/music/A$AP+Rocky/_/AIR+FOR...
# 31     https://www.last.fm/music/Arctic+Monkeys/_/505
# 32        https://www.last.fm/music/A$AP+Rocky/_/Stfu
# 33  https://www.last.fm/music/Bruno+Mars/_/Locked+...
# 34  https://www.last.fm/music/Olivia+Dean/_/Man+I+...
# 35       https://www.last.fm/music/KATSEYE/_/Gabriela
# 36  https://www.last.fm/music/Sabrina+Carpenter/_/...
# 37  https://www.last.fm/music/A$AP+Rocky/_/Whiskey...
# 38         https://www.last.fm/music/b%C3%B4a/_/Duvet
# 39  https://www.last.fm/music/The+Neighbourhood/_/...
# 40  https://www.last.fm/music/Bruno+Mars/_/That%27...
# 41  https://www.last.fm/music/Gorillaz/_/Feel+Good...
# 42    https://www.last.fm/music/TV+Girl/_/Lovers+Rock
# 43  https://www.last.fm/music/Tate+McRae/_/Sports+car
# 44  https://www.last.fm/music/A$AP+Rocky/_/DON%27T...
# 45  https://www.last.fm/music/The+Goo+Goo+Dolls/_/...
# 46  https://www.last.fm/music/Billie+Eilish/_/BIRD...
# 47     https://www.last.fm/music/Prince/_/Purple+Rain
# 48    https://www.last.fm/music/Tame+Impala/_/Dracula
# 49     https://www.last.fm/music/A$AP+Rocky/_/ROBBERY
#
#                           streamable             artist  \
# 0   {'#text': '0', 'fulltrack': '0'}                Djo
# 1   {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 2   {'#text': '0', 'fulltrack': '0'}     PinkPantheress
# 3   {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 4   {'#text': '0', 'fulltrack': '0'}        Addison Rae
# 5   {'#text': '0', 'fulltrack': '0'}       Taylor Swift
# 6   {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 7   {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 8   {'#text': '0', 'fulltrack': '0'}         Bruno Mars
# 9   {'#text': '0', 'fulltrack': '0'}               RAYE
# 10  {'#text': '0', 'fulltrack': '0'}       Zara Larsson
# 11  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 12  {'#text': '0', 'fulltrack': '0'}           EsDeeKid
# 13  {'#text': '0', 'fulltrack': '0'}          She & Him
# 14  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 15  {'#text': '0', 'fulltrack': '0'}       Zara Larsson
# 16  {'#text': '0', 'fulltrack': '0'}              sombr
# 17  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 18  {'#text': '0', 'fulltrack': '0'}          Radiohead
# 19  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 20  {'#text': '0', 'fulltrack': '0'}        Tame Impala
# 21  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 22  {'#text': '0', 'fulltrack': '0'}       Jeff Buckley
# 23  {'#text': '0', 'fulltrack': '0'}      Chappell Roan
# 24  {'#text': '0', 'fulltrack': '0'}         The Police
# 25  {'#text': '0', 'fulltrack': '0'}         The Marías
# 26  {'#text': '0', 'fulltrack': '0'}        Olivia Dean
# 27  {'#text': '0', 'fulltrack': '0'}         The Marías
# 28  {'#text': '0', 'fulltrack': '0'}  Sabrina Carpenter
# 29  {'#text': '0', 'fulltrack': '0'}          Radiohead
# 30  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 31  {'#text': '0', 'fulltrack': '0'}     Arctic Monkeys
# 32  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 33  {'#text': '0', 'fulltrack': '0'}         Bruno Mars
# 34  {'#text': '0', 'fulltrack': '0'}        Olivia Dean
# 35  {'#text': '0', 'fulltrack': '0'}            KATSEYE
# 36  {'#text': '0', 'fulltrack': '0'}  Sabrina Carpenter
# 37  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 38  {'#text': '0', 'fulltrack': '0'}                bôa
# 39  {'#text': '0', 'fulltrack': '0'}  The Neighbourhood
# 40  {'#text': '0', 'fulltrack': '0'}         Bruno Mars
# 41  {'#text': '0', 'fulltrack': '0'}           Gorillaz
# 42  {'#text': '0', 'fulltrack': '0'}            TV Girl
# 43  {'#text': '0', 'fulltrack': '0'}         Tate McRae
# 44  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
# 45  {'#text': '0', 'fulltrack': '0'}  The Goo Goo Dolls
# 46  {'#text': '0', 'fulltrack': '0'}      Billie Eilish
# 47  {'#text': '0', 'fulltrack': '0'}             Prince
# 48  {'#text': '0', 'fulltrack': '0'}        Tame Impala
# 49  {'#text': '0', 'fulltrack': '0'}         A$AP Rocky
#
#                                                 image
# 0   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 1   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 2   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 3   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 4   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 5   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 6   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 7   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 8   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 9   [{'#text': 'https://lastfm.freetls.fastly.net/...
# 10  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 11  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 12  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 13  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 14  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 15  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 16  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 17  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 18  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 19  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 20  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 21  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 22  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 23  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 24  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 25  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 26  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 27  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 28  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 29  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 30  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 31  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 32  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 33  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 34  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 35  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 36  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 37  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 38  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 39  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 40  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 41  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 42  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 43  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 44  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 45  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 46  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 47  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 48  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 49  [{'#text': 'https://lastfm.freetls.fastly.net/...

# %%
df_tracks = df_tracks[["name", 
                       "duration",
                       "playcount",
                       "listeners",
                      "artist"]]

# %%
df_tracks.to_csv("top_tracks_lastfm.csv", index = False)
